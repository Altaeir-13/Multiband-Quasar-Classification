# %% [markdown]
# # SDSS Image Sample Exploration
#
# Use this notebook after generating `data/processed/image_sample/metadata.csv`.

# %%
from pathlib import Path
import pandas as pd

metadata_path = Path('../../data/processed/image_sample/metadata.csv')
metadata = pd.read_csv(metadata_path)
metadata.head()

# %%
metadata.groupby(['split', 'class']).size().unstack(fill_value=0)

# %%
metadata[['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z', 'u_g', 'g_r', 'r_i', 'i_z']].describe()
